# %%
import os
import tensorflow as tf

# 🔥 GPU CHECK
print("TensorFlow version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))

# 🔥 Prevent GPU memory issues
gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
# Out:
# TensorFlow version: 2.10.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU memory growth enabled

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense,
    Flatten, Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %%
BASE_DIR = r"D:\plant_disease_prediction\dataset\apple"

TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "test")

IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 30

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

val_generator = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

NUM_CLASSES = train_generator.num_classes
print("Classes:", train_generator.class_indices)
# Out:
# Found 7771 images belonging to 4 classes.
# Found 1943 images belonging to 4 classes.
# Classes: {'apple_scab': 0, 'black_rot': 1, 'cedar_apple_rust': 2, 'healthy': 3}

# %%
model = Sequential([

    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),

    Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  batch_normalization (BatchN  (None, 222, 222, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 109, 109, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 52, 52, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 24, 24, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 256)               9437440
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 9,828,804
# Trainable params: 9,827,844
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "trained_models/best_apple_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/30
# 243/243 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.8336
# Epoch 1: val_accuracy improved from -inf to 0.22748, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 335s 1s/step - loss: 0.5394 - accuracy: 0.8336 - val_loss: 15.6266 - val_accuracy: 0.2275
# Epoch 2/30
# 243/243 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9093
# Epoch 2: val_accuracy improved from 0.22748 to 0.50180, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 63s 258ms/step - loss: 0.2613 - accuracy: 0.9093 - val_loss: 3.8283 - val_accuracy: 0.5018
# Epoch 3/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9346
# Epoch 3: val_accuracy improved from 0.50180 to 0.92589, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 68s 278ms/step - loss: 0.1881 - accuracy: 0.9346 - val_loss: 0.2284 - val_accuracy: 0.9259
# Epoch 4/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9480
# Epoch 4: val_accuracy improved from 0.92589 to 0.95780, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 61s 248ms/step - loss: 0.1598 - accuracy: 0.9480 - val_loss: 0.1231 - val_accuracy: 0.9578
# Epoch 5/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9568
# Epoch 5: val_accuracy did not improve from 0.95780
# 243/243 [==============================] - 59s 241ms/step - loss: 0.1315 - accuracy: 0.9568 - val_loss: 0.2145 - val_accuracy: 0.9434
# Epoch 6/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9609
# Epoch 6: val_accuracy improved from 0.95780 to 0.96294, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 57s 234ms/step - loss: 0.1268 - accuracy: 0.9609 - val_loss: 0.1129 - val_accuracy: 0.9629
# Epoch 7/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9654
# Epoch 7: val_accuracy improved from 0.96294 to 0.97581, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 57s 233ms/step - loss: 0.1154 - accuracy: 0.9654 - val_loss: 0.0957 - val_accuracy: 0.9758
# Epoch 8/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9668
# Epoch 8: val_accuracy did not improve from 0.97581
# 243/243 [==============================] - 57s 232ms/step - loss: 0.1067 - accuracy: 0.9668 - val_loss: 0.1730 - val_accuracy: 0.9490
# Epoch 9/30
# 243/243 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9659
# Epoch 9: val_accuracy did not improve from 0.97581
# 243/243 [==============================] - 57s 232ms/step - loss: 0.1103 - accuracy: 0.9659 - val_loss: 0.1889 - val_accuracy: 0.9557
# Epoch 10/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9673
# Epoch 10: val_accuracy improved from 0.97581 to 0.98405, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 57s 232ms/step - loss: 0.0982 - accuracy: 0.9673 - val_loss: 0.0725 - val_accuracy: 0.9840
# Epoch 11/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9765
# Epoch 11: val_accuracy did not improve from 0.98405
# 243/243 [==============================] - 60s 248ms/step - loss: 0.0774 - accuracy: 0.9765 - val_loss: 0.1010 - val_accuracy: 0.9779
# Epoch 12/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9749
# Epoch 12: val_accuracy did not improve from 0.98405
# 243/243 [==============================] - 57s 233ms/step - loss: 0.0828 - accuracy: 0.9749 - val_loss: 0.1338 - val_accuracy: 0.9650
# Epoch 13/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9762
# Epoch 13: val_accuracy did not improve from 0.98405
# 243/243 [==============================] - 57s 232ms/step - loss: 0.0850 - accuracy: 0.9762 - val_loss: 0.1969 - val_accuracy: 0.9454
# Epoch 14/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9784
# Epoch 14: val_accuracy improved from 0.98405 to 0.98507, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 57s 233ms/step - loss: 0.0737 - accuracy: 0.9784 - val_loss: 0.0508 - val_accuracy: 0.9851
# Epoch 15/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9786
# Epoch 15: val_accuracy did not improve from 0.98507
# 243/243 [==============================] - 56s 231ms/step - loss: 0.0730 - accuracy: 0.9786 - val_loss: 0.0853 - val_accuracy: 0.9763
# Epoch 16/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9822
# Epoch 16: val_accuracy did not improve from 0.98507
# 243/243 [==============================] - 62s 255ms/step - loss: 0.0579 - accuracy: 0.9822 - val_loss: 0.0589 - val_accuracy: 0.9840
# Epoch 17/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9831
# Epoch 17: val_accuracy improved from 0.98507 to 0.98610, saving model to trained_models\best_apple_model.h5
# 243/243 [==============================] - 60s 247ms/step - loss: 0.0628 - accuracy: 0.9831 - val_loss: 0.0558 - val_accuracy: 0.9861
# Epoch 18/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9784
# Epoch 18: val_accuracy did not improve from 0.98610
# 243/243 [==============================] - 64s 263ms/step - loss: 0.0755 - accuracy: 0.9784 - val_loss: 0.1018 - val_accuracy: 0.9748
# Epoch 19/30
# 243/243 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9839
# Epoch 19: val_accuracy did not improve from 0.98610
# 243/243 [==============================] - 63s 257ms/step - loss: 0.0564 - accuracy: 0.9839 - val_loss: 0.1313 - val_accuracy: 0.9712
